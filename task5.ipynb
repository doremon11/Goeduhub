# %% [markdown]
# <a href="https://colab.research.google.com/github/doremon11/Goeduhub-GO_STP_4414-/blob/main/task5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment/Task 5
# Reg No.:GO_STP_4414
# Name: Kala Sri Sowmya

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9ec4c6d2-3fe8-4367-94d7-c5448ce8a0fe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ec4c6d2-3fe8-4367-94d7-c5448ce8a0fe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving archive.zip to archive.zip
# ...

# %%
import pandas as pd
import numpy as np

ap= pd.read_csv("archive.zip")

# %%
ap.head()
# Out:
#    Unnamed: 0   State  ... Semi.permanent.House  Temporary.House
# 0           1      AN  ...                 39.1             32.0
# 1           2      AN  ...                 33.3             38.7
# 2           3  Andhra  ...                 39.9              7.0
# 3           4  Andhra  ...                 37.6              9.6
# 4           5  Andhra  ...                 36.4              7.8
#
# [5 rows x 82 columns]

# %% [markdown]
# 3.Understand some basic information about the dataset and Inspect the dataframe Inspect the dataframe's columns, shapes, variable types etc.

# %%
ap.dtypes
# Out:
# Unnamed: 0                int64
# State                    object
# District                 object
# Persons                   int64
# Males                     int64
#                          ...
# Paved.approach.road      object
# Mud.approach.road        object
# Permanent.House         float64
# Semi.permanent.House    float64
# Temporary.House         float64
# Length: 82, dtype: object

# %%
ap.columns
# Out:
# Index(['Unnamed: 0', 'State', 'District', 'Persons', 'Males', 'Females',
#        'Growth..1991...2001.', 'Rural', 'Urban', 'Scheduled.Caste.population',
#        'Percentage...SC.to.total', 'Number.of.households',
#        'Household.size..per.household.', 'Sex.ratio..females.per.1000.males.',
#        'Sex.ratio..0.6.years.', 'Scheduled.Tribe.population',
#        'Percentage.to.total.population..ST.', 'Persons..literate',
#        'Males..Literate', 'Females..Literate', 'Persons..literacy.rate',
#        'Males..Literatacy.Rate', 'Females..Literacy.Rate', 'Total.Educated',
#        'Data.without.level', 'Below.Primary', 'Primary', 'Middle',
#        'Matric.Higher.Secondary.Diploma', 'Graduate.and.Above', 'X0...4.years',
#        'X5...14.years', 'X15...59.years', 'X60.years.and.above..Incl..A.N.S..',
#        'Total.workers', 'Main.workers', 'Marginal.workers', 'Non.workers',
#        'SC.1.Name', 'SC.1.Population', 'SC.2.Name', 'SC.2.Population',
# ...

# %%
ap.axes
# Out:
# [RangeIndex(start=0, stop=590, step=1),
#  Index(['Unnamed: 0', 'State', 'District', 'Persons', 'Males', 'Females',
#         'Growth..1991...2001.', 'Rural', 'Urban', 'Scheduled.Caste.population',
#         'Percentage...SC.to.total', 'Number.of.households',
#         'Household.size..per.household.', 'Sex.ratio..females.per.1000.males.',
#         'Sex.ratio..0.6.years.', 'Scheduled.Tribe.population',
#         'Percentage.to.total.population..ST.', 'Persons..literate',
#         'Males..Literate', 'Females..Literate', 'Persons..literacy.rate',
#         'Males..Literatacy.Rate', 'Females..Literacy.Rate', 'Total.Educated',
#         'Data.without.level', 'Below.Primary', 'Primary', 'Middle',
#         'Matric.Higher.Secondary.Diploma', 'Graduate.and.Above', 'X0...4.years',
#         'X5...14.years', 'X15...59.years', 'X60.years.and.above..Incl..A.N.S..',
#         'Total.workers', 'Main.workers', 'Marginal.workers', 'Non.workers',
# ...

# %%
ap.ndim
# Out:
# 2

# %%
ap.size
# Out:
# 48380

# %%
ap.shape
# Out:
# (590, 82)

# %%
ap.describe()
# Out:
#        Unnamed: 0       Persons  ...  Semi.permanent.House  Temporary.House
# count  590.000000  5.900000e+02  ...            590.000000       590.000000
# mean   295.500000  1.732902e+06  ...             32.856000        19.490051
# std    170.462606  1.329998e+06  ...             21.587237        20.760061
# min      1.000000  3.139400e+04  ...              1.000000         0.100000
# 25%    148.250000  8.127185e+05  ...             14.600000         3.400000
# 50%    295.500000  1.487712e+06  ...             28.850000        10.750000
# 75%    442.750000  2.395986e+06  ...             47.175000        30.175000
# max    590.000000  9.610788e+06  ...             95.000000        85.600000
#
# [8 rows x 47 columns]

# %%
ap.head(50).mean()
# Out:
# Unnamed: 0                                 2.550000e+01
# Persons                                    1.801774e+06
# Males                                      9.157397e+05
# Females                                    8.860344e+05
# Number.of.households                       3.849187e+05
# Household.size..per.household.             4.920000e+00
# Sex.ratio..females.per.1000.males.         9.405600e+02
# Sex.ratio..0.6.years.                      9.631600e+02
# Scheduled.Tribe.population                5.808531e+274
# Persons..literate                          9.315256e+05
# Males..Literate                            5.498308e+05
# Females..Literate                          3.816947e+05
# Persons..literacy.rate                     5.866080e+01
# Males..Literatacy.Rate                     6.807620e+01
# Females..Literacy.Rate                     4.858160e+01
# Total.Educated                             9.315256e+05
# Data.without.level                         3.254382e+04
# ...

# %% [markdown]
# 4.Data Selection – Indexing and Slicing data

# %%
m=ap['Males']
m
# Out:
# 0       170319
# 1        22653
# 2      1250958
# 3      1162905
# 4      1747968
#         ...
# 585    1298078
# 586    4916370
# 587    2241898
# 588    2500040
# 589    3564993
# Name: Males, Length: 590, dtype: int64

# %% [markdown]
# 5.Data Selection – Based on Conditional filtering

# %%
mo=ap[ap['Males']==ap['Males'].max()]
print(mo)
# Out:
#      Unnamed: 0 State  ... Semi.permanent.House  Temporary.House
# 586         587    WB  ...                 40.5             39.4
#
# [1 rows x 82 columns]

# %% [markdown]
# 6.Groupby operations

# %%
d=ap.groupby("Persons")["Graduate.and.Above"].mean().reset_index()
d.sort_values("Graduate.and.Above", ascending=False)
# Out:
#      Persons  Graduate.and.Above
# 587  8640419            868911.0
# 582  6537124            736744.0
# 572  4572876            654046.0
# 588  8934286            621001.0
# 586  8131849            595234.0
# ..       ...                 ...
# 5      41030               602.0
# 22    100980               415.0
# 202  1112243                 NaN
# 283  1439116                 NaN
# 377  1881514                 NaN
#
# [590 rows x 2 columns]

# %% [markdown]
# 7.Sorting operation

# %%
top = d.sort_values(["Graduate.and.Above","Persons"], ascending=False)
top.head(n=15)
# Out:
#      Persons  Graduate.and.Above
# 587  8640419            868911.0
# 582  6537124            736744.0
# 572  4572876            654046.0
# 588  8934286            621001.0
# 586  8131849            595234.0
# 585  7232555            551221.0
# 570  4343645            540339.0
# 580  5816519            479990.0
# 557  3829753            466744.0
# 550  3647834            371574.0
# 574  4718592            348464.0
# 565  4167999            344813.0
# 491  2860869            329431.0
# 579  5251071            326964.0
# 430  2267023            325459.0

# %% [markdown]
# 8.Dealing with missing values

# %%
ap.isna().any()
# Out:
# Unnamed: 0              False
# State                   False
# District                False
# Persons                 False
# Males                   False
#                         ...
# Paved.approach.road      True
# Mud.approach.road        True
# Permanent.House         False
# Semi.permanent.House    False
# Temporary.House         False
# Length: 82, dtype: bool

# %%
print(ap.isna().sum())
# Out:
# Unnamed: 0               0
# State                    0
# District                 0
# Persons                  0
# Males                    0
#                         ..
# Paved.approach.road     12
# Mud.approach.road       12
# Permanent.House          0
# Semi.permanent.House     0
# Temporary.House          0
# Length: 82, dtype: int64

# %% [markdown]
# 9.Dropping columns and null values

# %%
data_cleaned = ap.dropna()
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 296 to 313
# Data columns (total 82 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Unnamed: 0                              8 non-null      int64
#  1   State                                   8 non-null      object
#  2   District                                8 non-null      object
#  3   Persons                                 8 non-null      int64
#  4   Males                                   8 non-null      int64
#  5   Females                                 8 non-null      int64
#  6   Growth..1991...2001.                    8 non-null      object
#  7   Rural                                   8 non-null      object
#  8   Urban                                   8 non-null      object
#  9   Scheduled.Caste.population              8 non-null      object
# ...

# %% [markdown]
# 10.Apply( ) functions

# %%
top = data_cleaned.sort_values(["Graduate.and.Above","Primary"], ascending=False)[
    ["Females", "Graduate.and.Above", "Primary","Middle"]]
top.head(n=15)
# Out:
#      Females  Graduate.and.Above  Primary   Middle
# 297   222601             57683.0  43273.0  70823.0
# 298   196505             33010.0  44284.0  63063.0
# 296   181890             18800.0  40258.0  51767.0
# 310   158799             16154.0  67374.0  58941.0
# 313    65821              3025.0  25687.0  16973.0
# 309    31398              1351.0  14227.0   9422.0
# 312    26481              1124.0  12300.0   7393.0
# 308    29671               857.0  11786.0   6611.0
