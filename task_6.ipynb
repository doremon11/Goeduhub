# %% [markdown]
# <a href="https://colab.research.google.com/github/doremon11/Goeduhub/blob/main/task_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment/Task 6
# Reg No.:GO_STP_4414
# Name: Kala Sri Sowmya

# %% [markdown]
# 1.Load the necessary package for plotting using pyplot from matplotlib.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Plot a Basic line plot between days and car speed, put x axis label as days and y axis label as car speed and put title Car Speed Measurement.
#
# Example - Days(x-axis) represents 8 days and Speed represents a car’s speed.
#
# Days=[1,2,3,4,5,6,7,8]
#
# Speed=[60,62,61,58,56,57,46,63]

# %%
Days=[1,2,3,4,5,6,7,8]
Speed=[60,62,61,58,56,57,46,63]

# %%
plt.plot(Days,Speed)
plt.title("Car Speed Measurement")
plt.xlabel("Days")
plt.ylabel("Car Speed")
plt.show()

# %% [markdown]
# 2. Now to above car data apply some string formats like line style example green dotted line, marker shape like +, change markersize, markerface color etc.

# %%
plt.plot(Days,Speed,color='g',linestyle=':',marker='+',markersize='7',markerfacecolor='blue')
plt.title("Car Speed Measurement")
plt.xlabel("Days")
plt.ylabel("Car Speed")
plt.show()

# %% [markdown]
# 3. Plot Axes Labels, Chart title, Legend, Grid in Car minimum, Maximum and average speed in 8 days.
#
# days=[1,2,3,4,5,6,7,8]
#
# max_speed=[80,91,92,88,77,79,76,75]
#
# min_speed=[42,43,40,42,33,36,34,35]
#
# avg_speed=[46,58,57,56,40,42,41,36]

# %%
days=[1,2,3,4,5,6,7,8]
max_speed=[80,91,92,88,77,79,76,75]
min_speed=[42,43,40,42,33,36,34,35]
avg_speed=[46,58,57,56,40,42,41,36]
plt.plot(days,max_speed,'g',label='Car maximum', linewidth=5)
plt.plot(days,min_speed,'b',label='Car minimum', linewidth=5)
plt.plot(days,avg_speed,'c',label='Car average', linewidth=5)
plt.title('Car Speed')
plt.ylabel('Speed')
plt.xlabel('Days')
plt.legend()
plt.grid(True,color='r')

# %% [markdown]
# 4. Plotting a basic sine graph by adding more features. Adding Multiple plots by Superimposition like cosine wave.

# %%
import numpy as np

x = np.arange(0,4*np.pi,0.1)   # start,stop,step
y = np.sin(x)
z = np.cos(x)
plt.plot(x,y,x,z)
plt.xlabel('x values from 0 to 4pi')  # string must be enclosed with quotes '  '
plt.ylabel('sin(x) and cos(x)')
plt.title('Plot of sin and cos from 0 to 4pi')
plt.legend(['sin(x)', 'cos(x)'])      # legend entries as seperate strings in a list
plt.show()

# %% [markdown]
# 5. Plot Simple bar chart showing popularity of Programming Languages.
#
# Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
#
# Popularity = [56, 39, 34, 34, 29]
#
# Security = [44 ,36 ,55, 50, 42]

# %%
Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
Popularity = [56, 39, 34, 34, 29]
Security = [44 ,36 ,55, 50, 42]
plt.bar(Languages,Popularity,label="Popularity",color='pink',width=.5)
plt.xlabel('Languages')
plt.ylabel("Popularity ")
plt.title('Information')
plt.show()

# %% [markdown]
# Plot Multiple Bars showing Popularity and Security of major Programming Languages. Also Create Horizontal bar chart using barh function.

# %%
Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
Popularity = [56, 39, 34, 34, 29]
Security = [44 ,36 ,55, 50, 42]
  
X_axis = np.arange(len(Languages))
  
plt.bar(X_axis - 0.2, Popularity, 0.4, label = 'Popularity')
plt.bar(X_axis + 0.2, Security, 0.4, label = 'Security')
  
plt.xticks(X_axis, Languages)
plt.xlabel("Languages")
plt.ylabel("Popularity & Security Score")
plt.title("Popularity & Security of major Programming Languages")
plt.legend()
plt.show()

# %%
plt.barh(X_axis - 0.2, Popularity, 0.4, label = 'Popularity')
plt.barh(X_axis + 0.2, Security, 0.4, label = 'Security')
  
plt.yticks(X_axis, Languages)
plt.ylabel("Languages")
plt.xlabel("Popularity & Security Score")
plt.title("Popularity & Security of major Programming Languages")
plt.legend()
plt.show()

# %% [markdown]
# 6. Plot Histogram, We have a sample data of Students marks of various Students, we will try to plot number of Students by marks range and try to figure out how many Students are average, below-average and Excellent.
#
# Marks = [ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64]
#
# Histogram showing Below Average, Average and Execellent distribution
#
# 40-60: Below Average
#
# 60-80: Average
#
# 80-100: Excellent

# %%
Marks = np.array([61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64])
below_average = Marks[np.logical_and(Marks >= 40,Marks < 60)]
average = Marks[np.logical_and(Marks >= 60,Marks < 80)]
excellent = Marks[np.logical_and(Marks >= 80,Marks < 100)]

plt.figure(figsize=(12,6))
plt.hist(Marks, align='right', color='blue', edgecolor='black')
plt.xlabel('Bins')
plt.ylabel('Marks')
plt.title('Histogram of Marks')
plt.vlines([40, 60, 80,100], ymin=0, ymax=4, colors='k',linestyles='dashed')
plt.show()

# %%
print(f'No of Below Average students : {below_average.size}')
print(f'No of Average students : {average.size}')
print(f'No of Excellent students : {excellent.size}')
# Out:
# No of Below Average students : 5
# No of Average students : 8
# No of Excellent students : 4

# %% [markdown]
# 7. Titanic Data Set Download Data
#
# Load the data file
#
# (i) Create a pie chart presenting the male/female proportion
#
# (ii) Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
plt.figure(figsize=(8,8))
df.sex.value_counts().plot.pie(autopct='%.0f%%',labels=['Male','Female'],shadow = True,
startangle = 180)
plt.title('Count of Sex')
plt.show()

# %% [markdown]
# creating scatter plot

# %%
male = df[df['sex'] == 'male']
male.sex.value_counts()
# Out:
# male    577
# Name: sex, dtype: int64

# %%
female = df[df['sex'] == 'female']
female.sex.value_counts()
# Out:
# female    314
# Name: sex, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.scatter(male.fare,male.age,
label='Male',color='pink',marker='x')
plt.scatter(female.fare,female.age,
label='Female',color='grey',marker='*')
plt.xlabel('Fare')
plt.ylabel('Age')
plt.title('Scatter Plot')
plt.legend()
plt.show()
